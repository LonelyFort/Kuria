# %% [markdown]
# # TODO:
# 1. Create a parser that is able to convert CASIA downloaded data into dataloaders
# 1. Compare Pretrained model of TesseractOCR on handwritten documents of Chinese

# %%
try:
